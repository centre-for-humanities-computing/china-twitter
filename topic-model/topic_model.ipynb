# %%
import pandas as pd 
import pickle as pkl 
import altair as alt
Ç

# setting up matplotlib settings
# Source: https://towardsdatascience.com/making-matplotlib-beautiful-by-default-d0d41e3534fd
import matplotlib.pyplot as plt
import seaborn as sns 
import matplotlib.font_manager as font_manager
import pickle as pkl
import pyLDAvis.gensim as gm

#%matplotlib inline
from pandas.plotting import scatter_matrix
import seaborn as sns
sns.set(style="whitegrid")
import re
import pyLDAvis
from tqdm import tqdm

#### Imports
import pandas as pd 
import pickle as pkl 
import altair as alt
import numpy as np 

# setting up matplotlib settings
# Source: https://towardsdatascience.com/making-matplotlib-beautiful-by-default-d0d41e3534fd
import matplotlib.pyplot as plt
import seaborn as sns 
import matplotlib.font_manager as font_manager

#%matplotlib inline
from pandas.plotting import scatter_matrix
import seaborn as sns
sns.set(style="whitegrid")
import re
import pyLDAvis

import matplotlib.dates as mdates
import matplotlib.pyplot as plt


# font
font_dirs = ['/Library/Fonts', ]
font_files = font_manager.findSystemFonts(fontpaths=font_dirs)
font_list = font_manager.createFontList(font_files)
font_manager.fontManager.ttflist.extend(font_list)

plt.rcParams['font.family'] = 'DIN Condensed Bold'

# set matplotlib aesthetics
CB91_Blue = '#2CBDFE'
CB91_Green = '#47DBCD'
CB91_Pink = '#F3A0F2'
CB91_Purple = '#9D2EC5'
CB91_Violet = '#661D98'
CB91_Amber = '#F5B14C'

color_list = [CB91_Blue, CB91_Pink, CB91_Green, CB91_Amber,
              CB91_Purple, CB91_Violet]

plt.rcParams['axes.prop_cycle'] = plt.cycler(color=color_list)

sns.set(rc={
            'axes.axisbelow': False,
            'axes.edgecolor': 'lightgrey',
            'axes.facecolor': 'None',
            'axes.grid': False,
            'axes.labelcolor': 'dimgrey',
            'axes.spines.right': False,
            'axes.spines.top': False,
            'figure.facecolor': 'white',
            'lines.solid_capstyle': 'round',
            'patch.edgecolor': 'w',
            'patch.force_edgecolor': True,
            'text.color': 'dimgrey',
            'xtick.bottom': False,
            'xtick.color': 'dimgrey',
            'xtick.direction': 'out',
            'xtick.top': False,
            'ytick.color': 'dimgrey',
            'ytick.direction': 'out',
            'ytick.left': False,
            'ytick.right': False,
            'savefig.dpi': 800})

#plt.rcParams["savefig.dpi"] = 'figure'
sns.set_context("notebook", rc={"font.size":12,
                                "axes.titlesize":16,
                                "axes.labelsize":16})


from helper_functions import *

# %%
#! pip install -r requirements.txt

# %% [markdown]
# #### Loading in the topic models for diplomats and media

# %%
media_dict, diplo_dict = load_models()
# Out:
# /home/coder/.local/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /home/coder/.local/lib/python3.7/site-packages/scipy/sparse/sparsetools.py:21: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()

# %% [markdown]
# #### Visualizing the topic model for Diplomats

# %%
import warnings
warnings.filterwarnings("ignore", category = DeprecationWarning)
# Out:
# /home/coder/.local/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
diplo_vis = visualize_model(diplo_dict, sort_topics = False) 
diplo_vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0     -0.155982  0.000721       1        1  18.026854
# 1     -0.166844 -0.025423       2        1  17.790693
# 2     -0.143745  0.111297       3        1  16.021769
# 3     -0.123682 -0.073441       4        1  13.522119
# 4     -0.092278 -0.013760       5        1   6.510753
# 5     -0.071118 -0.027702       6        1   4.829021
# 6     -0.037448 -0.007760       7        1   2.874458
# 7     -0.009865  0.010960       8        1   2.016810
# 8      0.026950 -0.003196       9        1   1.188330
# 9      0.031164 -0.012056      10        1   1.571444
# 10    -0.012581  0.033503      11        1   1.876579
# 11     0.038487 -0.019501      12        1   0.964912
# 12     0.031013  0.024868      13        1   0.886212
# 13     0.052049  0.001916      14        1   0.362641
# 14     0.034962 -0.001229      15        1   0.483412
# 15     0.045825  0.010991      16        1   0.710881
# ...

# %% [markdown]
# #### Visualizing the topic model for Media

# %%
media_vis = visualize_model(media_dict, sort_topics = False) 
media_vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster      Freq
# topic
# 0     -0.082793  0.086884       1        1  5.134869
# 1      0.025703 -0.071677       2        1  4.590854
# 2      0.111919  0.071518       3        1  4.925300
# 3      0.049612  0.037377       4        1  4.427143
# 4      0.051985  0.030396       5        1  4.458802
# 5      0.031397  0.078035       6        1  4.835564
# 6      0.036816 -0.091595       7        1  4.214034
# 7      0.007017 -0.011496       8        1  5.376972
# 8      0.222767  0.145242       9        1  6.471474
# 9      0.017254 -0.000813      10        1  3.715416
# 10    -0.027610  0.064208      11        1  5.635628
# 11     0.020507 -0.045624      12        1  4.318308
# 12    -0.161451 -0.008554      13        1  6.014302
# 13    -0.012924  0.009212      14        1  4.008719
# 14    -0.087802  0.035386      15        1  4.788861
# 15    -0.222757 -0.020614      16        1  5.961394
# ...

# %%
pyLDAvis.save_html(diplo_vis, 'plots/topic_model_diplomat.html')
pyLDAvis.save_html(media_vis, 'plots/topic_model_media.html')
# Out:
# /home/coder/.local/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Additional code for exploration of the data

# %%
data, diplomats, media = prep_data()

# %%
tweet_count_plot_categories(data)
# Out:
# alt.Chart(...)

# %%
available_users(data)
# Out:
# ['ChinaCGMTL',
#  'AmbCina',
#  'ChinainVan',
#  'XHNews',
#  'QiushiJournal',
#  'ChinaEUMission',
#  'ChinaMissionGva',
#  'AmbassadeChine',
#  'ChinaDaily',
#  'CGTNOfficial',
#  'ChinaAmbUN',
#  'shen_shiwei',
#  'MFA_China',
#  'HuXijin_GT',
#  'ChinaInDenmark',
#  'globaltimesnews',
#  'ChinaEmbOttawa',
#  'ChineseEmbinUK',
#  'chinascio',
#  'ChnMission',
#  'SpokespersonHZM',
#  'ChinaEmbGermany',
#  'China_Lyon',
#  'AmbLiuXiaoMing',
#  'XinWen_Ch',
#  'GeneralkonsulDu',
#  'chinacgedi',
#  'chenweihua',
#  'ChnEmbassy_jp',
#  'consulat_de',
#  'ChnConsul_osaka',
#  'ChineseEmbinUS',
#  'ChinaCGCalgary',
#  'Amb_ChenXu',
#  'Chinamission2un',
#  'zlj517',
#  'ChinaConSydney',
#  'CHN_UN_NY',
#  'SpokespersonCHN',
#  'AmbCuiTiankai',
#  'ChinaMissionVie',
#  'CCGBelfast',
#  'PDChina',
#  'ChinaConsulate']

# %% [markdown]
# ### Set options

# %%
options = ['XinWen_Ch']

# %%
tweet_count_plot(data, options)
# Out:
# alt.Chart(...)

# %%
plot_bars_retweets(data, options)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Dominant dataframes

# %%
media_without = media[media["retweet"] != "retweeted"].reset_index(drop = True)

# %%
diplo_without = diplomats[diplomats["retweet"] != "retweeted"].reset_index(drop = True)

# %%
#dominant_topic(media_dict["model"], media_dict["corpus"], media_without["text"], "media_dominant")
#dominant_topic(diplo_dict["model"], diplo_dict["corpus"], diplo_without["text"], "diplo_dominant")
# Out:
# ...
# 100%|██████████| 25830/25830 [02:37<00:00, 164.06it/s]
#        Dominant_Topic  Topic_Perc_Contribution  \
# 0                 0.0                   0.7734
# 1                 5.0                   0.7622
# 2                 6.0                   0.7064
# 3                 4.0                   0.9140
# 4                 4.0                   0.8423
# ...               ...                      ...
# 25825             2.0                   0.6179
# 25826             6.0                   0.9204
# 25827             4.0                   0.6809
# 25828            11.0                   0.3497
# 25829             0.0                   0.6290
#
#                                                 Keywords  \
# 0      chinese, uk, cooperation, new, year, country, ...
# 1      uk, people, country, say, hope, chinese, china...
# 2      people, country, chinese, cooperation, thank, ...
# 3      say, people, un, usa, make, beijing, work, cou...
# ...

# %%
diplo_dominant, media_dominant = load_dominant_dfs()

# %%
for i, ele in enumerate(topic_threshold(diplo_dominant, 0, 0.9).head(2000)["Text"].values):
    print(f"{i}. {ele} \n")
# Out:
# 0. No one would've thought a little fishing village would one day become a world-class city and be home to leading companies like Tencent and Huawei. Let's travel back time through Pulitzer Prize winner Liu Heung Shing's lens to see what ground-breaking changes have taken place. https://t.co/HjkmH5tQdr
#
# 1. This year marks the fifth anniversary of the China-UK "Golden Era". China-UK relations face new opportunities. I hope that the Chinese media based in UK would continue to work hard and make China's story and story of China-UK cooperation heard throughout the world. https://t.co/Or8lkcdy4F
#
# 2. I am glad to hear Mr.Fang, Chairman of CCCUK, mention that Chinese companies in UK has created a large number of jobs, contributed to local economy, and become part of local communities. They are also committed to building a global UK after Brexit. https://t.co/BYIqMZA4p9
#
# ...

# %%
query_topic(diplo_dominant, 10000, 'WorldHealthOrganization')
# Out:
#        Dominant_Topic  Topic_Perc_Contribution  \
# 7966              1.0                   0.9600
# 14782             1.0                   0.9600
# 19029             0.0                   0.9588
# 25224             1.0                   0.9561
# 14807             1.0                   0.9561
# ...               ...                      ...
# 14731             0.0                   0.3685
# 9628              1.0                   0.3508
# 7235              3.0                   0.3444
# 1002              1.0                   0.3443
# 14878             6.0                   0.3392
#
#                                                 Keywords  \
# 7966   covid19, people, chinese, say, country, suppor...
# 14782  covid19, people, chinese, say, country, suppor...
# 19029  chinese, uk, cooperation, new, year, country, ...
# 25224  covid19, people, chinese, say, country, suppor...
# 14807  covid19, people, chinese, say, country, suppor...
# ...

# %%
for i, ele in enumerate(query_topic(diplo_dominant, 10000, "HK")["Text"].values):
    print(f"{i}. {ele} \n")
# Out:
# 0. In response to reports on riots in #US, Chinese FM spokesperson said:
#
# What words are some people &amp;media in USA using now? They condemn the incident, calling it 'violence,' 'thugs,' 'extremists,' &amp; 'disgrace.'
#
# What words did they use to describe riots in #HK? 'Beautiful sight'. https://t.co/Ui5XJWEjT2
#
# 1. #HongKong's achievements in controlling the pandemic, stabilizing the economy and addressing people's concerns are there for everyone to see. The Central Government of China will continue to support #HKSAR in scoring even greater achievements for the benefit of its residents. https://t.co/ojRRGtc6tr
#
# 2. China urges Britain to abandon its #DoubleStandards on #HongKong-related issues.
#
# During British colonial rule over HK, successive governors of HK were appointed by the British, HK did not have democracy, and the HK people never enjoyed real freedom.
# https://t.co/U8kqG41AEj https://t.co/DpVGl2LHSv
#
# ...
