# %%
'''
VMP 2022-03-05: explore theta
'''

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
# read file 
d = pd.read_csv("../data/author_topic_px.csv")

# %%
d.head(5)
# Out:
#        Unnamed: 0     var 0     var 1     var 2     var 3     var 4     var 5  \
# 0   AmbCuiTiankai  0.223663  0.172866  0.104872  0.126723  0.117319  0.029505
# 1  AmbLiuXiaoMing  0.241184  0.180019  0.147552  0.075325  0.040845  0.072933
# 2      Amb_ChenXu  0.139057  0.265198  0.082989  0.076491  0.055198  0.054208
# 3  AmbassadeChine  0.118890  0.107018  0.055467  0.100749  0.061408  0.018704
# 4      CCGBelfast  0.398426  0.019818  0.017167  0.015142  0.147773  0.012251
#
#       var 6     var 7     var 8  ...    var 21    var 22    var 23    var 24  \
# 0  0.042077  0.015865  0.003560  ...  0.008831  0.000149  0.000144  0.001592
# 1  0.020918  0.016964  0.009044  ...  0.003519  0.012255  0.001420  0.005064
# 2  0.040819  0.018773  0.016100  ...  0.000325  0.010891  0.001386  0.006766
# 3  0.033197  0.018122  0.022110  ...  0.001283  0.003094  0.002943  0.011654
# 4  0.011184  0.010288  0.000000  ...  0.000000  0.000000  0.000000  0.242886
#
# ...
