# %% [markdown]
# # China Twitter Investigation

# %%
#### Imports
import pandas as pd 
import pickle as pkl 
import altair as alt
import numpy as np 
import os 

# setting up matplotlib settings
# Source: https://towardsdatascience.com/making-matplotlib-beautiful-by-default-d0d41e3534fd
import matplotlib.pyplot as plt
import seaborn as sns 
import matplotlib.font_manager as font_manager

#%matplotlib inline
from pandas.plotting import scatter_matrix
import seaborn as sns
sns.set(style="whitegrid")
import re
import pyLDAvis

import matplotlib.dates as mdates
import matplotlib.pyplot as plt

from helper_functions import *
# Out:
# /home/cnsome/helper_functions.py:48: MatplotlibDeprecationWarning:
# The createFontList function was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use FontManager.addfont instead.
#   font_list = font_manager.createFontList(font_files)
# /home/cnsome/china_twitter/lib/python3.6/site-packages/ipykernel_launcher.py:30: MatplotlibDeprecationWarning:
# The createFontList function was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use FontManager.addfont instead.

# %% [markdown]
# ### Topic Models

# %%
media_dict, diplo_dict = load_models()
# Out:
# /home/cnsome/china_twitter/lib/python3.6/site-packages/scipy/sparse/sparsetools.py:21: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()
# /home/cnsome/china_twitter/lib/python3.6/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
media_model, diplo_model = media_dict["model"], diplo_dict["model"]

# %%
media_model.print_topics()

# %% [markdown]
# #### Media

# %%
visualize_model(media_dict, sort_topics = False)
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster      Freq
# topic
# 0     -0.211459  0.016283       1        1  5.390264
# 1     -0.082555 -0.150279       2        1  5.133179
# 2      0.018010 -0.040121       3        1  5.016008
# 3     -0.129221 -0.076191       4        1  4.990225
# 4     -0.144568  0.077715       5        1  4.525938
# 5      0.110436  0.097112       6        1  4.901855
# 6      0.064295  0.206549       7        1  5.161821
# 7     -0.029109  0.064540       8        1  5.342536
# 8      0.017949 -0.001972       9        1  4.658189
# 9     -0.143251 -0.042276      10        1  4.754501
# 10     0.173825 -0.123069      11        1  5.295213
# 11    -0.105548  0.012257      12        1  4.399528
# 12     0.150939 -0.086701      13        1  5.191705
# 13     0.039676 -0.188506      14        1  5.141844
# 14    -0.085363  0.026096      15        1  4.640851
# 15     0.086573  0.252964      16        1  5.248612
# ...

# %% [markdown]
# #### Diplomat

# %%
visualize_model(diplo_dict, sort_topics = False)
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster      Freq
# topic
# 0      0.047457 -0.008155       1        1  2.499069
# 1      0.025902  0.034464       2        1  2.664260
# 2      0.040868 -0.010081       3        1  2.440872
# 3      0.047811  0.006681       4        1  2.824452
# 4     -0.058724 -0.032924       5        1  3.716772
# 5      0.008069  0.008056       6        1  2.816562
# 6      0.051229  0.065764       7        1  3.302058
# 7     -0.090166 -0.139535       8        1  4.637045
# 8     -0.118548  0.071166       9        1  5.057692
# 9      0.035219 -0.009076      10        1  2.494342
# 10     0.044209  0.000773      11        1  2.433199
# 11    -0.043469 -0.031174      12        1  4.384235
# 12     0.047896 -0.003575      13        1  2.538664
# 13     0.051106 -0.009598      14        1  2.474777
# 14     0.041486 -0.017776      15        1  3.022917
# 15     0.022774 -0.048728      16        1  4.346308
# ...
